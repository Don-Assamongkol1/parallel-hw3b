# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Idle Lock Overhead

# %%
Ws = [25, 50, 100, 200, 400, 800]

# for Locktype = TAS
LockFreeStrategyTimes = [6019.923828,
5702.596191,
6847.432129,
9360.271484,
13078.572266,
22712.673828]

HomeQueueStrategyTimes = [5985.182129,
6724.905762,
7532.721191,
9669.364258,
13158.760742,
21942.097656]

TASHomeQueueToLockFreeRatio = [HomeQueueStrategyTimes[i] / LockFreeStrategyTimes[i] for i in range(len(LockFreeStrategyTimes))]

# for LockType = TTAS
LockFreeStrategyTimes = [6920.930176,
6588.411133,
7248.188965,
9404.538086,
13028.867188,
21856.316406]

HomeQueueStrategyTimes = [5871.310059,
6583.979004,
7061.03418,
9652.152344,
13191.123047,
22022.832031]

TTASHomeQueueToLockFreeRatio = [HomeQueueStrategyTimes[i] / LockFreeStrategyTimes[i] for i in range(len(LockFreeStrategyTimes))]


plt.plot(Ws,
TASHomeQueueToLockFreeRatio,
marker='x'
)
plt.plot(Ws,
TTASHomeQueueToLockFreeRatio,
marker='x'
)

plt.legend(["TAS", "TTAS"])
plt.title("Execution Time Ratio of HomeQueueStrategy vs LockFreeStrategy")
plt.xlabel("Work per Packet (W)")
plt.ylabel("Ratio")
# Out:
# Text(0, 0.5, 'Ratio')

# %% [markdown]
# # Speedup with Exponential Load

# %%
serial_time = [5108.453857500001, 10205.973633, 15341.072754, 358.04451, 6.5915, 0.1545]

parallel_time_LockFree = [5752.067627, 6551.8344725, 7360.7558595, 113.8725015, 26.0464995, 1.802]
parallel_time_HomeQueue_TAS = [0.236, 0.257, 0.2845, 0.39449999999999996, 0.6025, 1.5445]
parallel_time_HomeQueue_TTAS = [0.2295, 0.2475, 0.295, 0.4985, 0.8625, 1.811]

parallel_time_LockFree_speedup = [parallel_time_LockFree[i] / serial_time[i] for i in range(len(parallel_time_LockFree))]
parallel_time_HomeQueue_TAS_speedup = [parallel_time_HomeQueue_TAS[i] / serial_time[i] for i in range(len(parallel_time_HomeQueue_TAS))]
parallel_time_HomeQueue_TTAS_speedup = [parallel_time_HomeQueue_TTAS[i] / serial_time[i] for i in range(len(parallel_time_HomeQueue_TTAS))]

ns = [1, 2, 3, 7, 13, 27]
numThreads = [1 + elem for elem in ns]

plt.plot(numThreads,
parallel_time_LockFree_speedup,
marker='x'
)
plt.plot(numThreads,
parallel_time_HomeQueue_TAS_speedup,
marker='x'
)
plt.plot(numThreads,
parallel_time_HomeQueue_TTAS_speedup,
marker='x'
)

plt.legend(["parallel_time_LockFree_speedup", "parallel_time_HomeQueue_TAS_speedup", "parallel_time_HomeQueue_TTAS_speedup"])
plt.title("W=1000 Ratio of Execution Time between (Strategy, Lock) permutation versus Serial Time")
plt.xlabel("Number of Threads (n + 1)")
plt.ylabel("Ratio")
# Out:
# Text(0, 0.5, 'Ratio')

# %%
serial_time = [5006.63501, 10013.875488000001, 15020.236816, 352.3964995, 6.5440000000000005, 0.1545]

parallel_time_LockFree = [5424.9138185, 6186.5197755, 6803.938964999999, 115.8919985, 15.927, 1.6715]
parallel_time_HomeQueue_TAS = [0.2315, 0.252, 0.274, 0.3845, 0.5865, 1.5245]
parallel_time_HomeQueue_TTAS = [0.22849999999999998, 0.2485, 0.27849999999999997, 0.4955, 0.8694999999999999, 2.0435]

parallel_time_LockFree_speedup = [parallel_time_LockFree[i] / serial_time[i] for i in range(len(parallel_time_LockFree))]
parallel_time_HomeQueue_TAS_speedup = [parallel_time_HomeQueue_TAS[i] / serial_time[i] for i in range(len(parallel_time_HomeQueue_TAS))]
parallel_time_HomeQueue_TTAS_speedup = [parallel_time_HomeQueue_TTAS[i] / serial_time[i] for i in range(len(parallel_time_HomeQueue_TTAS))]

ns = [1, 2, 3, 7, 13, 27]
numThreads = [1 + elem for elem in ns]

plt.plot(numThreads,
parallel_time_LockFree_speedup,
marker='x'
)
plt.plot(numThreads,
parallel_time_HomeQueue_TAS_speedup,
marker='x'
)
plt.plot(numThreads,
parallel_time_HomeQueue_TTAS_speedup,
marker='x'
)

plt.legend(["parallel_time_LockFree_speedup", "parallel_time_HomeQueue_TAS_speedup", "parallel_time_HomeQueue_TTAS_speedup"])
plt.title("W=2000 Ratio of Execution Time between (Strategy, Lock) permutation versus Serial Time")
plt.xlabel("Number of Threads (n + 1)")
plt.ylabel("Ratio")
# Out:
# Text(0, 0.5, 'Ratio')

# %%
serial_time = [4960.4660645, 9925.1181645, 14891.224121, 350.15499850000003, 6.402, 0.12]

parallel_time_LockFree = [5164.5231935, 5944.6760255, 6555.838623, 110.3429985, 20.9215, 1.1295]
parallel_time_HomeQueue_TAS = [0.2385, 0.2595, 0.262, 0.39449999999999996, 0.8955, 1.7414999999999998]
parallel_time_HomeQueue_TTAS = [0.2385, 0.2755, 0.3075, 0.593, 0.9045000000000001, 1.9965000000000002]

parallel_time_LockFree_speedup = [parallel_time_LockFree[i] / serial_time[i] for i in range(len(parallel_time_LockFree))]
parallel_time_HomeQueue_TAS_speedup = [parallel_time_HomeQueue_TAS[i] / serial_time[i] for i in range(len(parallel_time_HomeQueue_TAS))]
parallel_time_HomeQueue_TTAS_speedup = [parallel_time_HomeQueue_TTAS[i] / serial_time[i] for i in range(len(parallel_time_HomeQueue_TTAS))]

ns = [1, 2, 3, 7, 13, 27]
numThreads = [1 + elem for elem in ns]

plt.plot(numThreads,
parallel_time_LockFree_speedup,
marker='x'
)
plt.plot(numThreads,
parallel_time_HomeQueue_TAS_speedup,
marker='x'
)
plt.plot(numThreads,
parallel_time_HomeQueue_TTAS_speedup,
marker='x'
)

plt.legend(["parallel_time_LockFree_speedup", "parallel_time_HomeQueue_TAS_speedup", "parallel_time_HomeQueue_TTAS_speedup"])
plt.title("W=4000 Ratio of Execution Time between (Strategy, Lock) permutation versus Serial Time")
plt.xlabel("Number of Threads (n + 1)")
plt.ylabel("Ratio")
# Out:
# Text(0, 0.5, 'Ratio')

# %%
serial_time = [3946.7869870000004, 7896.053955, 11841.96875, 276.82699549999995, 4.665, 0.12]

parallel_time_LockFree = [4032.0469970000004, 4659.496094, 5125.8815915, 84.20849999999999, 22.540999499999998, 1.182]
parallel_time_HomeQueue_TAS =[0.236, 0.255, 0.268, 0.3505, 0.864, 1.737]
parallel_time_HomeQueue_TTAS =[0.2455, 0.254, 0.2935, 0.6025, 0.901, 1.675]

parallel_time_LockFree_speedup = [parallel_time_LockFree[i] / serial_time[i] for i in range(len(parallel_time_LockFree))]
parallel_time_HomeQueue_TAS_speedup = [parallel_time_HomeQueue_TAS[i] / serial_time[i] for i in range(len(parallel_time_HomeQueue_TAS))]
parallel_time_HomeQueue_TTAS_speedup = [parallel_time_HomeQueue_TTAS[i] / serial_time[i] for i in range(len(parallel_time_HomeQueue_TTAS))]

ns = [1, 2, 3, 7, 13, 27]
numThreads = [1 + elem for elem in ns]

plt.plot(numThreads,
parallel_time_LockFree_speedup,
marker='x'
)
plt.plot(numThreads,
parallel_time_HomeQueue_TAS_speedup,
marker='x'
)
plt.plot(numThreads,
parallel_time_HomeQueue_TTAS_speedup,
marker='x'
)

plt.legend(["parallel_time_LockFree_speedup", "parallel_time_HomeQueue_TAS_speedup", "parallel_time_HomeQueue_TTAS_speedup"])
plt.title("W=8000 Ratio of Execution Time between (Strategy, Lock) permutation versus Serial Time")
plt.xlabel("Number of Threads (n + 1)")
plt.ylabel("Ratio")
# Out:
# Text(0, 0.5, 'Ratio')

# %% [markdown]
# # Speedup with Uniform Load

# %%
serial_time = [505.891998, 1010.973022, 1515.800049, 35.380001, 0.671, 0.1]

parallel_time_LockFree =[570.651001, 604.651001, 609.578003, 14.398, 26.073999, 1.202]
parallel_time_HomeQueue_TAS =[0.238, 0.278, 0.293, 0.424, 0.898, 1.656]
parallel_time_HomeQueue_TTAS =[0.248, 0.267, 0.284, 0.524, 0.819, 1.589]

parallel_time_LockFree_speedup = [parallel_time_LockFree[i] / serial_time[i] for i in range(len(parallel_time_LockFree))]
parallel_time_HomeQueue_TAS_speedup = [parallel_time_HomeQueue_TAS[i] / serial_time[i] for i in range(len(parallel_time_HomeQueue_TAS))]
parallel_time_HomeQueue_TTAS_speedup = [parallel_time_HomeQueue_TTAS[i] / serial_time[i] for i in range(len(parallel_time_HomeQueue_TTAS))]

ns = [1, 2, 3, 7, 13, 27]
numThreads = [1 + elem for elem in ns]

plt.plot(numThreads,
parallel_time_LockFree_speedup,
marker='x'
)
plt.plot(numThreads,
parallel_time_HomeQueue_TAS_speedup,
marker='x'
)
plt.plot(numThreads,
parallel_time_HomeQueue_TTAS_speedup,
marker='x'
)

plt.legend(["parallel_time_LockFree_speedup", "parallel_time_HomeQueue_TAS_speedup", "parallel_time_HomeQueue_TTAS_speedup"])
plt.title("W=1000 Ratio of Execution Time between (Strategy, Lock) permutation versus Serial Time")
plt.xlabel("Number of Threads (n + 1)")
plt.ylabel("Ratio")
# Out:
# Text(0, 0.5, 'Ratio')

# %%
serial_time = [496.983002, 997.187012, 1496.305054, 35.080002, 0.655, 0.1]

parallel_time_LockFree =[527.812012, 546.086975, 562.473999, 8.658, 8.938, 1.212]
parallel_time_HomeQueue_TAS =[0.246, 0.267, 0.267, 0.369, 1.144, 1.781]
parallel_time_HomeQueue_TTAS =[0.253, 0.282, 0.304, 0.531, 0.894, 1.639]

parallel_time_LockFree_speedup = [parallel_time_LockFree[i] / serial_time[i] for i in range(len(parallel_time_LockFree))]
parallel_time_HomeQueue_TAS_speedup = [parallel_time_HomeQueue_TAS[i] / serial_time[i] for i in range(len(parallel_time_HomeQueue_TAS))]
parallel_time_HomeQueue_TTAS_speedup = [parallel_time_HomeQueue_TTAS[i] / serial_time[i] for i in range(len(parallel_time_HomeQueue_TTAS))]

ns = [1, 2, 3, 7, 13, 27]
numThreads = [1 + elem for elem in ns]

plt.plot(numThreads,
parallel_time_LockFree_speedup,
marker='x'
)
plt.plot(numThreads,
parallel_time_HomeQueue_TAS_speedup,
marker='x'
)
plt.plot(numThreads,
parallel_time_HomeQueue_TTAS_speedup,
marker='x'
)

plt.legend(["parallel_time_LockFree_speedup", "parallel_time_HomeQueue_TAS_speedup", "parallel_time_HomeQueue_TTAS_speedup"])
plt.title("W=2000 Ratio of Execution Time between (Strategy, Lock) permutation versus Serial Time")
plt.xlabel("Number of Threads (n + 1)")
plt.ylabel("Ratio")
# Out:
# Text(0, 0.5, 'Ratio')

# %%
serial_time = [495.194, 987.870972, 1484.170044, 34.650002, 0.713, 0.04]

parallel_time_LockFree =[509.627014, 523.856995, 529.26001, 6.535, 0.909, 1.185]
parallel_time_HomeQueue_TAS =[0.201, 0.253, 0.298, 0.369, 0.914, 1.809]
parallel_time_HomeQueue_TTAS =[0.303, 0.315, 0.356, 0.568, 0.964, 1.758]

parallel_time_LockFree_speedup = [parallel_time_LockFree[i] / serial_time[i] for i in range(len(parallel_time_LockFree))]
parallel_time_HomeQueue_TAS_speedup = [parallel_time_HomeQueue_TAS[i] / serial_time[i] for i in range(len(parallel_time_HomeQueue_TAS))]
parallel_time_HomeQueue_TTAS_speedup = [parallel_time_HomeQueue_TTAS[i] / serial_time[i] for i in range(len(parallel_time_HomeQueue_TTAS))]

ns = [1, 2, 3, 7, 13, 27]
numThreads = [1 + elem for elem in ns]

plt.plot(numThreads,
parallel_time_LockFree_speedup,
marker='x'
)
plt.plot(numThreads,
parallel_time_HomeQueue_TAS_speedup,
marker='x'
)
plt.plot(numThreads,
parallel_time_HomeQueue_TTAS_speedup,
marker='x'
)

plt.legend(["parallel_time_LockFree_speedup", "parallel_time_HomeQueue_TAS_speedup", "parallel_time_HomeQueue_TTAS_speedup"])
plt.title("W=4000 Ratio of Execution Time between (Strategy, Lock) permutation versus Serial Time")
plt.xlabel("Number of Threads (n + 1)")
plt.ylabel("Ratio")
# Out:
# Text(0, 0.5, 'Ratio')

# %%
serial_time = [396.269012, 787.344971, 1182.86499, 27.775, 0.563, 0.001]

parallel_time_LockFree =[402.079987, 408.876007, 413.268005, 16.023001, 0.939, 1.109]
parallel_time_HomeQueue_TAS =[0.241, 0.238, 0.257, 0.421, 0.9, 1.622]
parallel_time_HomeQueue_TTAS =[0.242, 0.287, 0.309, 0.555, 0.856, 1.549]

parallel_time_LockFree_speedup = [parallel_time_LockFree[i] / serial_time[i] for i in range(len(parallel_time_LockFree))]
parallel_time_HomeQueue_TAS_speedup = [parallel_time_HomeQueue_TAS[i] / serial_time[i] for i in range(len(parallel_time_HomeQueue_TAS))]
parallel_time_HomeQueue_TTAS_speedup = [parallel_time_HomeQueue_TTAS[i] / serial_time[i] for i in range(len(parallel_time_HomeQueue_TTAS))]

ns = [1, 2, 3, 7, 13, 27]
numThreads = [1 + elem for elem in ns]

plt.plot(numThreads,
parallel_time_LockFree_speedup,
marker='x'
)
plt.plot(numThreads,
parallel_time_HomeQueue_TAS_speedup,
marker='x'
)
plt.plot(numThreads,
parallel_time_HomeQueue_TTAS_speedup,
marker='x'
)

plt.legend(["parallel_time_LockFree_speedup", "parallel_time_HomeQueue_TAS_speedup", "parallel_time_HomeQueue_TTAS_speedup"])
plt.title("W=8000 Ratio of Execution Time between (Strategy, Lock) permutation versus Serial Time")
plt.xlabel("Number of Threads (n + 1)")
plt.ylabel("Ratio")
# Out:
# Text(0, 0.5, 'Ratio')

# %% [markdown]
# # Speedup with Awesome

# %%
Ws = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000]

awesomeTimes = [89.653, 84.883003, 88.303001, 128.164001, 370.102997, 205.860001, 531.393005, 200.712006]
HomeQueueStrategyTimes = [1434.498047, 3220.288086, 3564.975098, 5195.407227, 4452.64502, 2234.170898, 2086.648926, 2717.126953]

awesomeRatio = [HomeQueueStrategyTimes[i] / awesomeTimes[i] for i in range(len(HomeQueueStrategyTimes))]


plt.plot(Ws,
awesomeRatio,
marker='x'
)

plt.title("Speedup of Awesome Strategy vs HomeQueue Strategy")
plt.xlabel("Work per Packet (W)")
plt.ylabel("Ratio")
# Out:
# Text(0, 0.5, 'Ratio')
