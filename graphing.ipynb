# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Idle Lock Overhead

# %%
Ws = [25, 50, 100, 200, 400, 800]

# for Locktype = TAS
LockFreeStrategyTimes = [6019.923828,
5702.596191,
6847.432129,
9360.271484,
13078.572266,
22712.673828]

HomeQueueStrategyTimes = [5985.182129,
6724.905762,
7532.721191,
9669.364258,
13158.760742,
21942.097656]

# for LockType = TTAS
LockFreeStrategyTimes = [6920.930176,
6588.411133,
7248.188965,
9404.538086,
13028.867188,
21856.316406]

HomeQueueStrategyTimes = [5871.310059,
6583.979004,
7061.03418,
9652.152344,
13191.123047,
22022.832031]

for (n, speedup) in n_and_speedups:
    plt.plot(W_options,
    speedup,
    marker='x'
    )

plt.legend(["n=2", "n=9", "n=14"])
plt.title("Ratio of Serial-Queue to Serial")
plt.xlabel("Work per Packet (W)")
plt.ylabel("Ratio Serial-Queue to Serial")

# %% [markdown]
# # Lock Scaling Test

# %%
n_and_speedups = [(2, [1.0214132762312635, 1.0375265518055228, 1.0188724897169128]),
(9, [1.0545000693385107, 1.0294601260619347, 1.0226763348714567]),
(14, [1.0381062355658197, 1.0347400926402472, 1.0082931055823738])]

for (n, speedup) in n_and_speedups:
    plt.plot(W_options,
    speedup,
    marker='x'
    )

plt.legend(["n=2", "n=9", "n=14"])
plt.title("Ratio of Serial-Queue to Serial")
plt.xlabel("Work per Packet (W)")
plt.ylabel("Ratio Serial-Queue to Serial")
# Out:
# Text(0, 0.5, 'Ratio Serial-Queue to Serial')
